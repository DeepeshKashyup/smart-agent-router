# %% [markdown]
# # Smart Agent Router - Evaluation
#
# Run and visualize evaluation results for the routing pipeline.

# %%
import sys
import json
sys.path.insert(0, '..')

from pathlib import Path

# Load test cases
with open(Path('../eval/test_cases.json')) as f:
    test_cases = json.load(f)

print(f"Loaded {len(test_cases)} test cases")
for tc in test_cases:
    print(f"  [{tc['expected_complexity']}] {tc['query'][:60]}...")

# %% [markdown]
# ## Run Evaluation
#
# Execute `make eval` from the project root or run the cells below.

# %%
# To run the full evaluation pipeline:
# !cd .. && python eval/run_eval.py
